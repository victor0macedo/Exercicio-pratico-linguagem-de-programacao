# %% [markdown]
# # Atividade Prática — Aula 5: Visualização de Dados para Decisões com Matplotlib e Seaborn
#
# Esta atividade foi construída com base nos slides da Aula 5, cujo foco é transformar dados limpos em **gráficos que apoiem decisões**, e não em imagens decorativas. A aula reforça que o bom gráfico reduz esforço cognitivo, responde uma pergunta de negócio e precisa ser claro, comparável, simples e honesto. fileciteturn6file0
#
# ## Regras desta atividade
# - Você deve **construir os códigos**.
# - O notebook orienta os passos, mas não entrega a solução pronta.
# - Após cada gráfico principal, escreva uma **interpretação curta** em markdown.
# - O gráfico deve ser tratado como parte do seu portfólio: título, unidade, ordenação e mensagem importam. fileciteturn6file0
#
# ## Dataset da atividade
# Arquivo: `vendas_brasil_clean_aula5.csv`

# %% [markdown]
# ## 1. Preparação do ambiente
#
# Importe as bibliotecas necessárias para trabalhar com:
# - manipulação de dados
# - gráficos com Matplotlib
# - gráficos com Seaborn
#
# **Sugestão:**
# - `pandas`
# - `matplotlib.pyplot`
# - `seaborn`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Leitura da base
#
# Leia o arquivo `vendas_brasil_clean_aula5.csv` em um DataFrame chamado `df`.
#
# Depois:
# 1. exiba as primeiras linhas
# 2. verifique o tamanho da base
# 3. confira os tipos das colunas
# 4. observe quais variáveis podem ser usadas para:
#    - comparação
#    - tendência
#    - distribuição
#    - relação entre métricas

# %%
df = pd.read_csv('vendas_brasil_clean_aula5.csv')

print('Primeiras 5 linhas do DataFrame:')
display(df.head())

print('\nTamanho da base (linhas, colunas):', df.shape)

print('\nTipos das colunas:')
display(df.info())
# Out:
# Primeiras 5 linhas do DataFrame:
#          data  uf  canal_venda     segmento   categoria         produto  \
# 0  2024-03-17  SC  Marketplace       Varejo  Acessórios     Mouse Gamer
# 1  2024-08-28  BA       Online       Varejo  Acessórios     Mouse Gamer
# 2  2024-11-08  RJ  Marketplace  Corporativo      Móveis  Cadeira Office
# 3  2024-08-21  RJ       Online       Varejo  Acessórios     Headset Pro
# 4  2024-03-14  RJ   Televendas  Corporativo  Acessórios     Headset Pro
#
#    quantidade  preco_unitario  receita      lucro  margem_lucro      mes
# 0           3          221.45   664.35  -110.6595     -0.166568  2024-03
# 1           3          195.52   586.56   232.5600      0.396500  2024-08
# 2           9         1079.28  9713.52  3416.6700      0.351700  2024-11
# 3           3          309.43   928.29   416.8800      0.449100  2024-08
# 4           6          313.42  1880.52   778.5600      0.414000  2024-03
# Tamanho da base (linhas, colunas): (480, 12)
#
# Tipos das colunas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            480 non-null    object
#  1   uf              480 non-null    object
#  2   canal_venda     480 non-null    object
#  3   segmento        480 non-null    object
#  4   categoria       480 non-null    object
#  5   produto         480 non-null    object
#  6   quantidade      480 non-null    int64
#  7   preco_unitario  480 non-null    float64
#  8   receita         480 non-null    float64
#  9   lucro           480 non-null    float64
#  10  margem_lucro    480 non-null    float64
#  11  mes             480 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 45.1+ KB
# None

# %% [markdown]
# ## 3. Traduzindo a pergunta em gráfico
#
# A aula destaca que a escolha do gráfico nunca é aleatória: a pergunta define a visualização. fileciteturn6file0
#
# ### Tarefa
# Preencha em markdown pelo menos 4 exemplos no formato:
#
# - **Pergunta do gestor:** ...
# - **Variáveis (Pandas):** ...
# - **Tipo de gráfico:** ...
# - **Biblioteca sugerida:** ...
#
# Use como referência a matriz mostrada nos slides:
# - evolução no tempo → linha
# - ranking/comparação entre grupos → barras
# - variabilidade e outliers → boxplot
# - correlação entre duas métricas → scatter

# %% [markdown]
# ## 3. Traduzindo a pergunta em gráfico
#
# A aula destaca que a escolha do gráfico nunca é aleatória: a pergunta define a visualização.
#
# ### Tarefa
# Preencha em markdown pelo menos 4 exemplos no formato:
#
# - **Pergunta do gestor:** ...
# - **Variáveis (Pandas):** ...
# - **Tipo de gráfico:** ...
# - **Biblioteca sugerida:** ...
#
# Use como referência a matriz mostrada nos slides:
# - evolução no tempo → linha
# - ranking/comparação entre grupos → barras
# - variabilidade e outliers → boxplot
# - correlação entre duas métricas → scatter
#
# ---
#
# - **Pergunta do gestor:** Como a receita evoluiu ao longo do tempo?
# - **Variáveis (Pandas):** `data` (eixo X), `receita` (eixo Y)
# - **Tipo de gráfico:** Linha
# - **Biblioteca sugerida:** `matplotlib.pyplot` ou `seaborn`
#
# - **Pergunta do gestor:** Qual produto gera mais lucro?
# - **Variáveis (Pandas):** `produto` (eixo Y), `lucro` (eixo X)
# - **Tipo de gráfico:** Barras horizontais
# - **Biblioteca sugerida:** `seaborn` ou `matplotlib.pyplot`
#
# - **Pergunta do gestor:** Qual a distribuição da margem de lucro por categoria de produto e há outliers?
# - **Variáveis (Pandas):** `categoria` (eixo categórico), `margem_lucro` (eixo numérico)
# - **Tipo de gráfico:** Boxplot
# - **Biblioteca sugerida:** `seaborn`
#
# - **Pergunta do gestor:** Existe alguma relação entre a quantidade vendida e a receita total?
# - **Variáveis (Pandas):** `quantidade` (eixo X), `receita` (eixo Y)
# - **Tipo de gráfico:** Scatter plot
# - **Biblioteca sugerida:** `seaborn`

# %% [markdown]
# ## 4. Gráfico de barras horizontais — Qual canal gera mais caixa?
#
# A missão prática do slide pede responder: **qual canal gera mais caixa?** fileciteturn6file0
#
# ### Tarefa
# 1. Agrupe a receita por `canal_venda`
# 2. Ordene os valores
# 3. Gere um gráfico de **barras horizontais**
# 4. Use rótulos e título claros
# 5. Certifique-se de que a visualização esteja limpa e fácil de ler
#
# ### Lembretes da aula
# - barras são o padrão-ouro para rankings e comparações
# - ordenação é obrigatória para facilitar a leitura
# - se os rótulos forem longos, barras horizontais ajudam

# %%
receita_por_canal = df.groupby('canal_venda')['receita'].sum().sort_values(ascending=True)

plt.figure(figsize=(10, 6))
sns.barplot(x=receita_por_canal.values, y=receita_por_canal.index, palette='viridis')

plt.title('Receita Total por Canal de Venda', fontsize=16)
plt.xlabel('Receita Total (em Reais)', fontsize=12)
plt.ylabel('Canal de Venda', fontsize=12)

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2610/3229015504.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=receita_por_canal.values, y=receita_por_canal.index, palette='viridis')

# %% [markdown]
# ### Insight obrigatório
#
# O canal **Online** lidera com a maior receita, enquanto a **Loja Física** apresenta a menor. Um gestor poderia investigar as estratégias da Loja Física para identificar gargalos e oportunidades de aumento de vendas, talvez aprendendo com o sucesso dos canais digitais ou explorando sinergias.

# %% [markdown]
# ## 5. Gráfico de linha — Como é a sazonalidade ao longo dos meses?
#
# Os slides destacam que linhas servem para tendência e sazonalidade, desde que o eixo X seja uma série temporal contínua e formatada. fileciteturn6file0
#
# ### Tarefa
# 1. Agrupe a `receita` por `mes`
# 2. Gere um gráfico de linha temporal
# 3. Remova ruídos visuais desnecessários
# 4. Use um título que diga **o que aconteceu**, não apenas o nome das colunas
#
# ### Dica
# Pense na diferença entre:
# - “Receita por mês”
# - “Receita acelera no fim do ano”

# %%
month_order_pt = [
    'Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
    'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'
]

df['mes'] = pd.Categorical(df['mes'], categories=month_order_pt, ordered=True)

receita_por_mes = df.groupby('mes')['receita'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x='mes', y='receita', data=receita_por_mes, marker='o', color='skyblue')

plt.title('Receita Anual Acelera no Final do Ano, Atingindo Picos em Dezembro', fontsize=16)
plt.xlabel('Mês', fontsize=12)
plt.ylabel('Receita Total (em Reais)', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2610/2013366064.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   receita_por_mes = df.groupby('mes')['receita'].sum().reset_index()

# %% [markdown]
# ### Insight obrigatório
#
# - **Existe sazonalidade?** Sim, o gráfico mostra que as vendas mudam bastante ao longo do ano.
# - **Há meses de pico?** Sim, a receita aumenta muito no final do ano, com Dezembro sendo o mês de maior pico.
# - **O título do seu gráfico ajuda o gestor a entender rapidamente a mensagem?** Sim, o título já diz que a receita sobe no fim do ano, o que ajuda o gestor a pegar a mensagem principal logo de cara.

# %% [markdown]
# ## 6. Boxplot — A margem oscila por segmento?
#
# Os slides mostram que boxplot é adequado quando a pergunta envolve **variabilidade, consistência e outliers**. fileciteturn6file0
#
# ### Tarefa
# 1. Use `segmento` no eixo categórico
# 2. Use `margem_lucro` como variável numérica
# 3. Gere um **boxplot** com Seaborn
# 4. Observe dispersão, mediana e possíveis outliers
#
# ### Perguntas
# - Qual segmento parece mais estável?
# - Existe maior risco ou variabilidade em algum deles?
# - Há outliers relevantes?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='segmento', y='margem_lucro', data=df, palette='pastel')

plt.title('Distribuição da Margem de Lucro por Segmento', fontsize=16)
plt.xlabel('Segmento', fontsize=12)
plt.ylabel('Margem de Lucro', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2610/3852807846.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='segmento', y='margem_lucro', data=df, palette='pastel')

# %% [markdown]
# ### Insight obrigatório
#
# O segmento **Varejo** mostra margens de lucro mais consistentes, sendo uma aposta mais estável. Já o **Corporativo** apresenta maior variabilidade e outliers, indicando mais risco e a necessidade de investigar transações específicas de alta ou baixa margem. Isso pode levar a uma decisão de focar no Varejo para receita previsível e otimizar processos no Corporativo para mitigar riscos e replicar sucessos.

# %% [markdown]
# ## 7. Scatter plot — Produto que fatura muito, dá lucro?
#
# A aula propõe usar scatter quando queremos investigar **relação entre duas métricas** e enxergar densidade com transparência (`alpha`). fileciteturn6file0
#
# ### Tarefa
# 1. Gere um scatter com:
#    - eixo X: `receita`
#    - eixo Y: `lucro`
# 2. Use transparência para melhorar a leitura
# 3. Observe se existe correlação
# 4. Procure anomalias: pontos com alta receita e lucro ruim, por exemplo
#
# ### Perguntas
# - A relação entre receita e lucro parece positiva?
# - Existem exceções preocupantes?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='receita', y='lucro', data=df, alpha=0.6, color='darkgreen')

plt.title('Relação entre Receita e Lucro', fontsize=16)
plt.xlabel('Receita Total (em Reais)', fontsize=12)
plt.ylabel('Lucro Total (em Reais)', fontsize=12)

plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight obrigatório
#
# Existe uma correlação visual positiva forte entre receita e lucro, ou seja, geralmente quanto maior a receita, maior o lucro. No entanto, há alguns pontos que indicam alta receita com lucro desproporcionalmente baixo, sugerindo anomalias. Um gestor deveria investigar esses casos específicos de alta receita com baixo lucro para entender os motivos (custos elevados, descontos excessivos, etc.) e otimizar a rentabilidade.

# %% [markdown]
# ## 8. Comunicação vs. decoração
#
# A aula mostra que visualização não é estética pela estética. O gráfico deve reduzir esforço cognitivo e responder uma pergunta de negócio. fileciteturn6file0
#
# ### Tarefa
# Escolha um dos gráficos que você produziu e revise:
# - título
# - nome dos eixos
# - unidade numérica
# - ordenação
# - excesso de linhas, bordas ou legendas
#
# Depois escreva:
# 1. O que você removeu?
# 2. O gráfico ficou mais fácil de interpretar?

# %%
receita_por_canal = df.groupby('canal_venda')['receita'].sum().sort_values(ascending=True)

plt.figure(figsize=(10, 6))
sns.barplot(x=receita_por_canal.values, y=receita_por_canal.index, color='skyblue')

plt.title('Vendas: Canal Online Lidera, Loja Física Têm Menor Receita', fontsize=16)
plt.xlabel('Receita Total (em Reais)', fontsize=12)
plt.ylabel('Canal de Venda', fontsize=12)

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Comunicação vs. decoração
#
# A aula mostra que visualização não é estética pela estética. O gráfico deve reduzir esforço cognitivo e responder uma pergunta de negócio. fileciteturn6file0
#
# ### Tarefa
# Escolha um dos gráficos que você produziu e revise:
# - título
# - nome dos eixos
# - unidade numérica
# - ordenação
# - excesso de linhas, bordas ou legendas
#
# Depois escreva:
# 1. O que você removeu?
# 2. O gráfico ficou mais fácil de interpretar?
#
# ---
#
# Refatorei o gráfico de barras `Receita Total por Canal de Venda`.
#
# 1.  **O que você removeu?**
#     *   **Título:** Mudei de 'Receita Total por Canal de Venda' (descritivo) para 'Vendas: Canal Online Lidera, Loja Física Têm Menor Receita' (analítico).
#     *   **Linhas de grade:** Removi as linhas de grade do eixo X para diminuir a poluição visual.
#     *   **Paleta de cores:** Substituí a paleta `viridis` por uma cor sólida (`skyblue`) para evitar distração, já que as cores não codificam nenhuma informação adicional neste gráfico de barra única.
#
# 2.  **O gráfico ficou mais fácil de interpretar?**
#     Sim, a interpretação ficou mais fácil. O novo título já entrega o principal insight, reduzindo o esforço cognitivo do leitor para entender a mensagem central. A remoção das linhas de grade e a simplificação da cor tornaram o gráfico visualmente mais limpo e direto, focando a atenção nos dados essenciais.

# %% [markdown]
# ## 10. Galeria dos vilões
#
# A aula apresenta três “vilões” que devem ser evitados:
# - pizza caótica
# - distorção 3D
# - arco-íris sem propósito fileciteturn6file0
#
# ### Tarefa
# Explique, em markdown:
# 1. Por que gráfico de pizza com muitas categorias costuma falhar?
# 2. Por que o 3D atrapalha comparações?
# 3. Por que usar muitas cores sem intenção gera confusão cognitiva?
#
# ---
#
# 1.  **Por que gráfico de pizza com muitas categorias costuma falhar?**
#     Com muitas fatias, fica impossível comparar os tamanhos e entender qual parte é maior ou menor. O olho humano tem dificuldade em julgar áreas pequenas e muitos detalhes juntos confundem.
#
# 2.  **Por que o 3D atrapalha comparações?**
#     A perspectiva 3D engana nossos olhos, fazendo com que algumas partes pareçam maiores ou menores do que realmente são, dependendo de onde estão no gráfico. Isso dificulta muito a comparação exata dos valores.
#
# 3.  **Por que usar muitas cores sem intenção gera confusão cognitiva?**
#     Se as cores não têm um significado claro, elas apenas distraem e cansam o cérebro. Em vez de ajudar a entender os dados, elas viram um ruído visual que desvia a atenção da mensagem principal.

# %% [markdown]
# ## 11. Storytelling — O gráfico não fala sozinho
#
# Um dos pontos mais fortes da aula é que **o título ideal é a conclusão da análise**, e não só a descrição dos eixos. fileciteturn6file0
#
# ### Tarefa
# Escolha **dois gráficos** que você criou e escreva:
# - um título meramente descritivo
# - um título analítico, orientado ao insight
#
# Exemplo de lógica:
# - Descritivo: “Receita e lucro por canal”
# - Analítico: “Online lidera receita, mas Loja Física retém maior margem”

# %% [markdown]
# ## 11. Storytelling — O gráfico não fala sozinho
#
# Um dos pontos mais fortes da aula é que **o título ideal é a conclusão da análise**, e não só a descrição dos eixos. fileciteturn6file0
#
# ### Tarefa
# Escolha **dois gráficos** que você criou e escreva:
# - um título meramente descritivo
# - um título analítico, orientado ao insight
#
# Exemplo de lógica:
# - Descritivo: “Receita e lucro por canal”
# - Analítico: “Online lidera receita, mas Loja Física retém maior margem”
#
# ---
#
# **Gráfico 1: Receita Total por Canal de Venda (Gráfico de Barras)**
# -   **Título Descritivo:** `Receita Total por Canal de Venda`
# -   **Título Analítico:** `Vendas: Canal Online Lidera, Loja Física Têm Menor Receita`
#
# **Gráfico 2: Receita Total por Mês (Gráfico de Linha)**
# -   **Título Descritivo:** `Receita Total por Mês`
# -   **Título Analítico:** `Receita Anual Acelera no Final do Ano, Atingindo Picos em Dezembro`

# %% [markdown]
# ## 13. Checklist do analista profissional
#
# Antes de terminar, revise seu trabalho com base no checklist da aula: fileciteturn6file0
#
# - O gráfico responde claramente à pergunta original?
# - Você removeu linhas, bordas e legendas que não agregam?
# - Os eixos estão honestos e não distorcem a realidade?
# - As cores foram usadas com intenção?
# - Há um pequeno texto explicando o insight?
#
# ### Tarefa
# Responda esse checklist em markdown, item por item.
#
# ---
#
# **Respostas ao Checklist:**
#
# -   **O gráfico responde claramente à pergunta original?**
#     Sim, todos os gráficos foram construídos com o objetivo de responder a uma pergunta de negócio específica (ex: 'Qual canal gera mais caixa?', 'Como a receita evoluiu ao longo do tempo?'), e os títulos analíticos ajudam a reforçar a resposta.
#
# -   **Você removeu linhas, bordas e legendas que não agregam?**
#     Sim, no processo de refatoração do gráfico de barras, foram removidas linhas de grade do eixo X para reduzir ruído visual. Outros gráficos foram criados com foco na simplicidade, evitando elementos desnecessários.
#
# -   **Os eixos estão honestos e não distorcem a realidade?**
#     Sim, os eixos foram mantidos honestos, sem cortes ou escalas manipuladas que pudessem distorcer a percepção dos dados. As unidades numéricas e os rótulos estão claros.
#
# -   **As cores foram usadas com intenção?**
#     Sim, as cores foram usadas com intenção. No gráfico de barras refatorado, uma cor sólida foi escolhida para evitar distração, já que a cor não codificava informações adicionais. Nos boxplots e scatter plots, paletas de cores padrão do Seaborn foram utilizadas para clareza, sem o uso de 'arco-íris sem propósito'.
#
# -   **Há um pequeno texto explicando o insight?**
#     Sim, após cada gráfico principal, um 'Insight obrigatório' foi fornecido em markdown, com 2 a 3 linhas, explicando a mensagem principal e as implicações para o negócio, transformando o gráfico em uma ferramenta para decisão.

# %% [markdown]
# ## 14. Desafio extra (opcional)
#
# Crie um gráfico adicional, escolhendo uma destas possibilidades:
# - receita por UF (barras ordenadas)
# - lucro por categoria (barras horizontais)
# - distribuição de receita por segmento (boxplot)
# - relação entre quantidade e lucro (scatter)
#
# Mas atenção:
# - o gráfico precisa responder uma pergunta real
# - o título precisa ser analítico
# - o texto interpretativo é obrigatório

# %%
# Desafio extra opcional

# %% [markdown]
# ## 15. Entrega esperada
#
# Seu notebook deve demonstrar:
# - organização
# - escolha correta do tipo de gráfico
# - uso adequado de Matplotlib e Seaborn
# - compromisso com clareza, comparabilidade, simplicidade e honestidade
# - interpretação escrita orientada a decisão
#
# ### Mensagem principal da aula
# Não basta plotar. É preciso **comunicar o sinal no meio do ruído**. fileciteturn6file0
